# %%
# import networkx as nx
# import numpy as np
# import collections

# a = np.matrix("""131 673 234 103 18;
#                  201 96 342 965 150;
#                  630 803 746 422 111;
#                  537 699 497 121 956;
#                  805 732 524 37 331""")

# rows, columns = b.shape

# # Part of @AustinHastings solution
# graph = collections.defaultdict(list)
# for r in range(rows):
#     for c in range(columns):
#         if c < columns - 1:
#            # get the right neighbor 
#            graph[(r, c)].append((r, c+1))
#         if r < rows - 1:
#            # get the bottom neighbor
#            graph[(r, c)].append((r+1, c))

# G = nx.from_dict_of_lists(graph, create_using=nx.DiGraph)

# weights = {(row, col): {'weight': num} for row, r in enumerate(a.tolist()) for col, num in enumerate(r)}
# nx.set_node_attributes(G, values=weights)

# def weight(u, v, d):
#     return G.nodes[u].get('weight')/2 + G.nodes[v].get('weight')/2

# target = tuple(i - 1 for i in a.shape)
# path = nx.dijkstra_path(G, source=(0, 0), target=target, weight=weight)
# print('Path: ', [a.item(i) for i in path])

# %matplotlib inline
# color_map = ['green' if n in path else 'red' for n in G.nodes()]
# labels = nx.get_node_attributes(G, 'weight')
# pos = {(r, c): (c, -r) for r, c in G.nodes()}
# nx.draw(G, pos=pos, with_labels=True, node_size=1500, labels = labels, node_color=color_map)

# %%
# import re
# import networkx as nx
# import matplotlib.pyplot as plt

# plt.style.use("ggplot")

# sentences = [
#     "I went out for a walk or walking.",
#     "When I was walking, I saw a cat. ",
#     "The cat was injured. ",
#     "My mum's name is Marylin.",
#     "While I was walking, I met John. ",
#     "Nothing has happened.",
# ]

# G = nx.Graph()
# # set of possible good words
# good_words = {"went", "walk", "cat", "walking"}

# # remove punctuation and keep only good words inside sentences
# words = list(
#     map(
#         lambda x: set(re.sub(r"[^\w\s]", "", x).lower().split()).intersection(
#             good_words
#         ),
#         sentences,
#     )
# )

# # convert sentences to dict for furtehr labeling
# sentences = {k: v for k, v in enumerate(sentences)}

# # add nodes
# for i, sentence in sentences.items():
#     G.add_node(i)

# # add edges if two nodes have the same word inside
# for i in range(len(words)):
#     for j in range(i + 1, len(words)):
#         for edge_label in words[i].intersection(words[j]):
#             G.add_edge(i, j, r=edge_label)

# # compute layout coords
# coord = nx.spring_layout(G)

# plt.figure(figsize=(20, 14))

# # set label coords a bit upper the nodes
# node_label_coords = {}
# for node, coords in coord.items():
#     node_label_coords[node] = (coords[0], coords[1] + 0.04)

# # draw the network
# nodes = nx.draw_networkx_nodes(G, pos=coord)
# edges = nx.draw_networkx_edges(G, pos=coord)
# edge_labels = nx.draw_networkx_edge_labels(G, pos=coord)
# node_labels = nx.draw_networkx_labels(G, pos=node_label_coords, labels=sentences)
# plt.title("Sentences network")
# plt.axis("off")

# %%
# def get_weighted_edges(document):
#     # in our case, relations are bigrams in sentences
#     # weights are number of equal bigrams
#     # use a dict to store number of counts
#     bigrams = {}
#     for sent in document:
#         for i in range(len(sent)-1):
        
#             # transform to hashable key in dict
#             pair = str([sent[i], sent[i+1]])
            
#             if pair not in bigrams.keys():
#                 # weight = 1
#                 bigrams[pair] = 1
#             else:
#                 # already exists, weight + 1
#                 bigrams[pair] += 1
                
#     # convert to NetworkX standard form each edge connecting nodes u and v = [u, v, weight]
#     weighted_edges_format = []
#     for pair, weight in bigrams.items():
#         # revert back from hashable format
#         w1, w2 = eval(pair)
#         weighted_edges_format.append([w1, w2, weight])
        
#     return weighted_edges_format

# %%
# def get_entities(document):
#     # in our case, entities are all unique words
#     unique_words = []
#     for sent in document:
#         for word in sent:
#             if word not in unique_words:
#                 unique_words.append(word)
#     return unique_words

# %%
# nodes = get_entities(b)

# # get weighted edges
# weighted_edges = get_weighted_edges(b)

# # create graph structure with NetworkX
# G = nx.DiGraph()
# G.add_nodes_from(nodes)
# G.add_weighted_edges_from(weighted_edges)

# %%
# nodes = []
# weighted_edges = []

# %%
# for i in range (0,3):
#   nodes.append(b[i][1])
#   weighted_edges.append(b[i][2])

# %%
# z = np.array(weighted_edges)

# %%
# x = nx.Graph()

# x.add_nodes_from(nodes)
# x.add_weighted_edges_from(b)

# # for t in range(0,3):
# #   # x.add_edge(nodes[t], nodes[t-1])
# #   x.add_weighted_edges_from(b)

# %%
# nx.draw_networkx(x, arrows = True, node_shape = 's', node_color = 'blue')

# %%
# u = nx.DiGraph()
# for b in range(0,5):
#   y = str([data.Word1[b]])
#   z = str([data.Word2[b]])
#   u.add_edge((y), (z))
# # for b in range(0,4):
# #   y = str([data.Word1[b]])
# #   z = str([data.Word2[b + 1]])
# #   u.add_edge((y), (z))

# nx.draw_networkx(u, with_labels = True)

# %%
# h = pd.crosstab(data.Word1, data.Word2)
# h

# %%
# h = h.sort_values('Word1')
# h

# %%
# G = nx.from_pandas_adjacency(h)
# nx.draw_networkx(G, with_labels = True)

# %%
# rows, cols = np.where(h == 1)
# edges = zip(rows.tolist(), cols.tolist())
# gr = nx.Graph()
# gr.add_edges_from(edges)
# nx.draw(gr, node_size=500, with_labels=True)
# plt.show()

# %%
# t = data.groupby(['Word1', 'Word2'])['Freq'].apply(lambda x : x.astype(int).sum())

# %%
# bigrams = []
# for u in range(0,5):
#   bigrams.append(l.Words[u])

# %%
# weighted_edges_format = []
# for i in range(0,5):
#     weighted_edges_format.append([data.Word1[i], data.Word2[i], data.Freq[i]])

# %%
# unique = []
# for word in data.Word1:
#     if word not in unique:
#         unique.append(word)

# for word in data.Word2:
#     if word not in unique:
#         unique.append(word)

# %%
# G = nx.DiGraph()
# G.add_nodes_from(unique)

# # G.add_weighted_edges_from(weighted_edges)
# nx.draw_networkx(G, arrows = True, node_color = 'green', arrowsize=5, arrowstyle='simple')

# %%
import pandas as pd
import numpy as np
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
import re

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# scaled_data = scaler.fit_transform(z.reshape(-1, 1))

# %%
name = 'Bi'

# %%
filepath = r'/content/drive/MyDrive/WS/Çıktılar/' + name + 'grams.csv'

# %%
b = (
      [
        [0, "['right', 'reserved']", 9004],
        [1, "['elsevier', 'ltd']", 4451],
        [2, "['right', 'ltd']", 4033],
        [3, "['right', 'elsevier']", 4750],
        [4, "['reserved', 'elsevier']", 1128],
        [5, "['reserved', 'ltd']", 1128],
        [6, "['a', 'b']", 9004],
        [7, "['a', 'c']", 4451],
        [8, "['b', 'c']", 4033],
        [9, "['c', 'd']", 4750],
        [10, "['d', 'a']", 1128],
        [11, "['d', 'b']", 1128],
        [12, "['b', 'ltd']", 1128],
        [13, "['a', 'ltd']", 9004],
      ]
    )

# %%
type(b)
# Out:
# list

# %%
# scaled_data = scaled_data.reshape(1, -1)

# %%
l = pd.DataFrame(b, columns=['Index','Words','Freq'])
l
# Out:
#     Index                     Words  Freq
# 0       0     ['right', 'reserved']  9004
# 1       1       ['elsevier', 'ltd']  4451
# 2       2          ['right', 'ltd']  4033
# 3       3     ['right', 'elsevier']  4750
# 4       4  ['reserved', 'elsevier']  1128
# 5       5       ['reserved', 'ltd']  1128
# 6       6                ['a', 'b']  9004
# 7       7                ['a', 'c']  4451
# 8       8                ['b', 'c']  4033
# 9       9                ['c', 'd']  4750
# 10     10                ['d', 'a']  1128
# 11     11                ['d', 'b']  1128
# 12     12              ['b', 'ltd']  1128
# 13     13              ['a', 'ltd']  9004

# %%
l = l.drop('Index', axis=1)

# %%
l['Words'] = l['Words'].map(lambda x: re.sub(r"'", '', x))
l['Words'] = l['Words'].map(lambda x: re.sub(r" ", '', x))

# %%
l
# Out:
#                   Words  Freq
# 0      [right,reserved]  9004
# 1        [elsevier,ltd]  4451
# 2           [right,ltd]  4033
# 3      [right,elsevier]  4750
# 4   [reserved,elsevier]  1128
# 5        [reserved,ltd]  1128
# 6                 [a,b]  9004
# 7                 [a,c]  4451
# 8                 [b,c]  4033
# 9                 [c,d]  4750
# 10                [d,a]  1128
# 11                [d,b]  1128
# 12              [b,ltd]  1128
# 13              [a,ltd]  9004

# %%
l.Freq = scaler.fit_transform(l[['Freq']])
l.Freq = abs(l.Freq)
l
# Out:
#                   Words      Freq
# 0      [right,reserved]  1.652459
# 1        [elsevier,ltd]  0.078851
# 2           [right,ltd]  0.065618
# 3      [right,elsevier]  0.182191
# 4   [reserved,elsevier]  1.069645
# 5        [reserved,ltd]  1.069645
# 6                 [a,b]  1.652459
# 7                 [a,c]  0.078851
# 8                 [b,c]  0.065618
# 9                 [c,d]  0.182191
# 10                [d,a]  1.069645
# 11                [d,b]  1.069645
# 12              [b,ltd]  1.069645
# 13              [a,ltd]  1.652459

# %%
l['Words'] = l['Words'].str.replace('[', '')
l['Words'] = l['Words'].str.replace(']', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
data = pd.DataFrame(l.Words.str.split(',',1).tolist(), columns = ['Word1','Word2'])
data['Freq'] = l.Freq
data
# Out:
#        Word1     Word2      Freq
# 0      right  reserved  1.652459
# 1   elsevier       ltd  0.078851
# 2      right       ltd  0.065618
# 3      right  elsevier  0.182191
# 4   reserved  elsevier  1.069645
# 5   reserved       ltd  1.069645
# 6          a         b  1.652459
# 7          a         c  0.078851
# 8          b         c  0.065618
# 9          c         d  0.182191
# 10         d         a  1.069645
# 11         d         b  1.069645
# 12         b       ltd  1.069645
# 13         a       ltd  1.652459

# %%
G = nx.from_pandas_edgelist(data, 'Word1', 'Word2', edge_attr ='Freq')
nx.draw_networkx(G, with_labels = True)
# plt.savefig("filename.png")

# %%
nx.draw_networkx(G, arrows = True, node_shape = 's', node_color = 'purple')
# plt.savefig("filenamewitharrow.png")

# %%
F = nx.from_pandas_edgelist(data, 'Word1', 'Word2', edge_attr ='Freq', create_using=nx.DiGraph)
nx.draw_networkx(F, arrows = True, node_shape = 'd', node_color = 'blue', arrowsize=7, arrowstyle='simple', edge_cmap = 'green')
nx.write_gpickle(F, "test.gpickle")
# plt.savefig("filenamewitharrow1.png")

# %%
nx.info(F)
# Out:
# 'DiGraph with 8 nodes and 14 edges'

# %%
def make_node_df(G):
    nodes = {}
    for node, attribute in G.nodes(data=True):
        if not nodes.get('node'):
            nodes['node'] = [node]
        else:
            nodes['node'].append(node)

        for key, value in attribute.items():
            if not nodes.get(key):
                nodes[key] = [value]
            else:
                nodes[key].append(value)

    return pd.DataFrame(nodes)

def make_edge_df(G):
    edges = {}
    for source, target, attribute in G.edges(data=True):

        if not edges.get('source'):
            edges['source'] = [source]
        else:
            edges['source'].append(source)

        if not edges.get('target'):
            edges['target'] = [target]
        else:
            edges['target'].append(target)

        for key, value in attribute.items():
            if not edges.get(key):
                edges[key] = [value]
            else:
                edges[key].append(value)
    return pd.DataFrame(edges)


def node_df_to_ebunch(df, nodename='node'):

    attributes = [col for col in df.columns if not col==nodename]

    ebunch = []

    for ix, row in df.iterrows():
        ebunch.append((row[nodename], {attribute:row[attribute] for attribute in attributes}))

    return ebunch

# %%
r = make_node_df(F)
ı = make_edge_df(F)
G = nx.DiGraph()
nodes = node_df_to_ebunch(r, nodename='node')
G.add_nodes_from(nodes)
# G.add_weighted_edges_from(ı)

# %%
r
# Out:
#        node
# 0     right
# 1  reserved
# 2  elsevier
# 3       ltd
# 4         a
# 5         b
# 6         c
# 7         d

# %%
ı
# Out:
#       source    target      Freq
# 0      right  reserved  1.652459
# 1      right       ltd  0.065618
# 2      right  elsevier  0.182191
# 3   reserved  elsevier  1.069645
# 4   reserved       ltd  1.069645
# 5   elsevier       ltd  0.078851
# 6          a         b  1.652459
# 7          a         c  0.078851
# 8          a       ltd  1.652459
# 9          b         c  0.065618
# 10         b       ltd  1.069645
# 11         c         d  0.182191
# 12         d         a  1.069645
# 13         d         b  1.069645

# %%
nx.draw_networkx(G, arrows = True, node_shape = 'd', node_color = 'blue', arrowsize=7, arrowstyle='simple', edge_cmap = 'green')

# %%
G = nx.from_pandas_edgelist(data, 'Word1', 'Word2', edge_attr =True)
nx.draw_networkx(G, with_labels = True)
# plt.savefig("filename.png")

# %%
F = nx.from_pandas_edgelist(data, 'Word1', 'Word2', edge_attr ='Freq', create_using=nx.MultiGraph)
nx.draw_networkx(F, arrows = True, node_shape = 's', node_color = 'purple', arrowsize=5, arrowstyle='fancy')
# plt.savefig("filenamewitharrow1.png")

# %%
F = nx.from_pandas_edgelist(data, 'Word1', 'Word2', edge_attr ='Freq', create_using=nx.MultiDiGraph)
nx.draw_networkx(F, arrows = True, node_color = 'purple', arrowsize=10, arrowstyle='simple')
# plt.savefig("filenamewitharrow1.png")

# %%
df2 = pd.read_csv(filepath, index_col=0)

# %%
df2
# Out:
#                              Words  Freq
# 0            ['right', 'reserved']  9004
# 1              ['elsevier', 'ltd']  4451
# 2                 ['ltd', 'right']  4033
# 3            ['elsevier', 'right']  2777
# 4             ['paper', 'present']  2200
# ...                            ...   ...
# 14975  ['downstream', 'signaling']    25
# 14976         ['smoking', 'habit']    25
# 14977     ['currently', 'limited']    25
# 14978     ['health', 'initiative']    25
# 14979           ['may', 'account']    25
#
# [14980 rows x 2 columns]

# %%
l = pd.DataFrame(df2, columns=['Words','Freq'])
l
# Out:
#                              Words  Freq
# 0            ['right', 'reserved']  9004
# 1              ['elsevier', 'ltd']  4451
# 2                 ['ltd', 'right']  4033
# 3            ['elsevier', 'right']  2777
# 4             ['paper', 'present']  2200
# ...                            ...   ...
# 14975  ['downstream', 'signaling']    25
# 14976         ['smoking', 'habit']    25
# 14977     ['currently', 'limited']    25
# 14978     ['health', 'initiative']    25
# 14979           ['may', 'account']    25
#
# [14980 rows x 2 columns]

# %%
l['Words'] = l['Words'].map(lambda x: re.sub(r"'", '', x))
l['Words'] = l['Words'].map(lambda x: re.sub(r" ", '', x))
l
# Out:
#                         Words  Freq
# 0            [right,reserved]  9004
# 1              [elsevier,ltd]  4451
# 2                 [ltd,right]  4033
# 3            [elsevier,right]  2777
# 4             [paper,present]  2200
# ...                       ...   ...
# 14975  [downstream,signaling]    25
# 14976         [smoking,habit]    25
# 14977     [currently,limited]    25
# 14978     [health,initiative]    25
# 14979           [may,account]    25
#
# [14980 rows x 2 columns]

# %%
l.Freq = scaler.fit_transform(l[['Freq']])
l.Freq = abs(l.Freq)
l
# Out:
#                         Words       Freq
# 0            [right,reserved]  67.913297
# 1              [elsevier,ltd]  33.310017
# 2                 [ltd,right]  30.133173
# 3            [elsevier,right]  20.587440
# 4             [paper,present]  16.202179
# ...                       ...        ...
# 14975  [downstream,signaling]   0.328050
# 14976         [smoking,habit]   0.328050
# 14977     [currently,limited]   0.328050
# 14978     [health,initiative]   0.328050
# 14979           [may,account]   0.328050
#
# [14980 rows x 2 columns]

# %%
data = pd.DataFrame(l.Words.str.split(',',1).tolist(), columns = ['Word1','Word2'])
data['Freq'] = l.Freq
data
# Out:
#              Word1        Word2       Freq
# 0           [right    reserved]  67.913297
# 1        [elsevier         ltd]  33.310017
# 2             [ltd       right]  30.133173
# 3        [elsevier       right]  20.587440
# 4           [paper     present]  16.202179
# ...            ...          ...        ...
# 14975  [downstream   signaling]   0.328050
# 14976     [smoking       habit]   0.328050
# 14977   [currently     limited]   0.328050
# 14978      [health  initiative]   0.328050
# 14979         [may     account]   0.328050
#
# [14980 rows x 3 columns]

# %%
# f = plt.figure()
# f.set_figwidth(250)
# f.set_figheight(250)

# %%
plt.figure(figsize=(260, 260))

# %%
F = nx.from_pandas_edgelist(data, 'Word1', 'Word2', create_using=nx.MultiDiGraph)
nx.draw_networkx(F, arrows = True, node_shape = 'd', node_color = 'blue', arrowsize=10, arrowstyle='simple', edge_cmap = 'green')
nx.write_gpickle(F, "model.gpickle")
# plt.savefig("final.png")

# %%
nx.info(F)
